# %% [markdown]
# ```
# 23일 토요일 각자 eda 후 올리기
# 24일 일요일 슬랙 또는 행아웃
#
#
# EDA 해볼 것
# 1. 사람이 어디서 어디로 가장 많이 이동하는 지. 새로운 노선 만들기(인구수가 많은 지역(유동인구), 정류장 이용 많은 곳)
# 2. 시간대 이용자 파악 후 버스 배차간격 조정 - 주중, 주말 나눠서 분석 (예측)
# 3. 신도시 버스 인프라 먼저 파악 (지하철x)
# 4. 서울에서 오는 버스가 어느 정류장에 서는지 확인
#
# 최적화 방법
# 1. 가장 많은 이용자가 있는 정류장 최단거리
# 2. 비용을 최소화 하는 방법 (최대한 노선 합치기)
# 3. 있는 노선 확인 후 사람을 많이 태우는 노선 추천(수요)
# ```

# %%
# %matplotlib inline

import geopandas as gpd

import pandas as pd
import os
import requests
import folium
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# import plotly.express as px
# import plotly.graph_objects as go

# %%
# matplotlib에 “AppleGothc”(Mac) 또는 “Malgun Gothic”(Windows) 글꼴 적용

import matplotlib.font_manager as fm

for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break

plt.rcParams['font.family']
# Out:
# ['Malgun Gothic']

# %%
#2018년 7월 승차일 기준 1~4일의 버스 카드태깅 정보를 담고있습니다.
TripChain = pd.read_csv('./Data/PJT001_TripChain.csv')

#17~18년 기준, 경기도 버스 정류장에 대한 정보를 담고있습니다.
StationTable = pd.read_csv('./Data/PJT001_stations_table.csv')

#2018년 7월 1~4일의 행정동별 이동 인구수 정보를 담고 있습니다.
AreaPeople = pd.read_csv('./Data/PJT001_sk_emd_od.csv')

#버스노선-정류장 매핑 테이블 정보 입니다.
RouteStationInfo = pd.read_csv('./Data/PJT001_routestationinfo.csv')

# %%
TripChain.columns=['암호화카드번호', '트랜잭션ID', '환승횟수', '교통카드발행사ID',
       '총이용객수', '사용자구분', '교통수단CD1', '교통수단CD2',
       '교통수단CD3', '교통수단CD4', '교통수단CD5', '버스노선ID1',
       '버스노선ID2', '버스노선ID3', '버스노선ID4', '버스노선ID5',
       '차량ID1', '차량ID2', '차량ID3', '차량ID4',
       '차량ID5', '총통행거리', '총탑승시간', '총소요시간',
       '승차일시1', '승차일시2', '승차일시3', '승차일시4',
       '승차일시5', '하차일시1', '하차일시2', '하차일시3',
       '하차일시4', '하차일시5', '최초승차일시', '최종하차일시',
       '승차역ID1', '승차역ID2', '승차역ID3', '승차역ID4',
       '승차역ID5', '하차역ID1', '하차역ID2', '하차역ID3',
       '하차역ID4', '하차역ID5', '최초승차역ID', '최종하차역ID',
       '총이용금액', '수집건수', '트립체인완료코드']

# %%
TripChain.head()
# Out:
#         암호화카드번호  트랜잭션ID  환승횟수  교통카드발행사ID  총이용객수  사용자구분  교통수단CD1  교통수단CD2  \
# 0  900079696430      56     2    9000923      1      1    500.0    500.0
# 1  900079697651       5     1    9000923      1      1    500.0      NaN
# 2  900079698254      32     1    9000923      1      1    500.0      NaN
# 3  900079699257      80     1    9000923      1      1    500.0      NaN
# 4  900079701419      64     1    9000923      1      1    530.0      NaN
#
#    교통수단CD3  교통수단CD4  ...  하차역ID1  하차역ID2  하차역ID3  하차역ID4  하차역ID5  최초승차역ID  \
# 0      NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 1      NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 2      NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 3      NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 4      NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
#
#      최종하차역ID  총이용금액  수집건수  트립체인완료코드
# 0  4116708.0   1350     2         ;
# 1  4117269.0   1250     1         ;
# 2  4107936.0   1550     1         ;
# 3  4116717.0   1250     1         ;
# 4  4116848.0   2050     1         ;
#
# [5 rows x 51 columns]

# %% [markdown]
# 날짜, 시간 데이터 datetime으로 데이터타입 변경

# %%
TripChain['승차일시1'] = pd.to_datetime(TripChain['승차일시1'], format='%Y%m%d%H%S%f')
TripChain['승차일시2'] = pd.to_datetime(TripChain['승차일시2'], format='%Y%m%d%H%S%f')
TripChain['승차일시3'] = pd.to_datetime(TripChain['승차일시3'], format='%Y%m%d%H%S%f')
TripChain['승차일시4'] = pd.to_datetime(TripChain['승차일시4'], format='%Y%m%d%H%S%f')
TripChain['승차일시5'] = pd.to_datetime(TripChain['승차일시5'], format='%Y%m%d%H%S%f')
TripChain['하차일시1'] = pd.to_datetime(TripChain['하차일시1'], format='%Y%m%d%H%S%f')
TripChain['하차일시2'] = pd.to_datetime(TripChain['하차일시2'], format='%Y%m%d%H%S%f')
TripChain['하차일시3'] = pd.to_datetime(TripChain['하차일시3'], format='%Y%m%d%H%S%f')
TripChain['하차일시4'] = pd.to_datetime(TripChain['하차일시4'], format='%Y%m%d%H%S%f')
TripChain['하차일시5'] = pd.to_datetime(TripChain['하차일시5'], format='%Y%m%d%H%S%f')

# %%
TripChain.shape
# Out:
# (1048575, 51)

# %%
TripChain['암호화카드번호'].nunique()
# Out:
# 498764

# %%
TripChain['승차일시1'].unique()
# Out:
# array(['2018-07-01T05:00:25.430000000', '2018-07-01T07:00:21.560000000',
#        '2018-07-01T12:00:36.530000000', ...,
#        '2018-07-04T14:00:02.590000000', '2018-07-04T09:00:49.560000000',
#        '2018-07-04T21:00:21.540000000'], dtype='datetime64[ns]')

# %% [markdown]
# ---

# %% [markdown]
# 버스노선-정류장 매핑 정보
# ```
# 'seq ' : 순번.
# 'pr_station_id' : 노선 ID.
# 'bus_line_no' : 버스 노선 번호.
# 'bus_line_no_seq' : 버스 라인 정류장 순서.
# 'station_nm ' : 정류장 명칭.
# 'station_id ' : 표준정류장ID.
# 'mobile_no' : 모바일정류장ID.
# ```

# %%
# 버스 개수
RouteStationInfo['bus_line_no'].nunique()
# Out:
# 226

# %%
RouteStationInfo.head()
# Out:
#      seq  pr_station_id bus_line_no  bus_line_no_seq station_nm  station_id  \
# 0  65286      228000018        10-4                1      용인터미널   228001552
# 1  65287      228000018        10-4                2  용인터미널(경유)   277102443
# 2  65288      228000018        10-4                3      포브스병원   228000443
# 3  65289      228000018        10-4                4       제일교회   228000665
# 4  65290      228000018        10-4                5     라이프아파트   228000664
#
#    mobile_no
# 0    47634.0
# 1        NaN
# 2    29439.0
# 3    29881.0
# 4    29457.0

# %%
StationTable.shape
# Out:
# (38509, 12)

# %%
StationTable.drop_duplicates(subset ="정류소번호", 
                     keep = 'first', inplace = True)

# %%
StationTable.shape
# Out:
# (31686, 12)

# %% [markdown]
# ## 버스별로 노선 확인 (Folium 이용)

# %%
StationTable.sample()
# Out:
#          표준정류장ID  시군명   정류소명           정류소영문명    정류소번호 중앙차로여부     관할관청  \
# 24908  233002404  화성시  태안교차로  Taean Junction   36192.0  노변정류장  경기도 화성시
#
#                 위치    WGS84위도    WGS84경도  \
# 24908  경기도 화성시 진안동  37.218383  127.03715
#
#                                                 모바일정류장ID  이비카드정류장ID
# 24908  [None None None None None None None None None ...  4117229.0

# %%
StationTable[StationTable['표준정류장ID'] == 228001552]
# Out:
#          표준정류장ID  시군명   정류소명            정류소영문명    정류소번호 중앙차로여부     관할관청  \
# 18624  228001552  용인시  용인터미널  Yongin Terminal   47634.0  노변정류장  경기도 용인시
#
#                      위치    WGS84위도   WGS84경도  \
# 18624  경기도 용인시 처인구 김량장동  37.232783  127.2101
#
#                                                 모바일정류장ID  이비카드정류장ID
# 18624  [None None None None None None None None None ...  4176783.0

# %%
RouteStationInfo_latlon = pd.merge(RouteStationInfo, 
             StationTable[['정류소명', '표준정류장ID', 'WGS84위도', 'WGS84경도', '관할관청']],
             left_on='station_id', right_on='표준정류장ID', how='left')

# %%
RouteStationInfo_latlon
# Out:
#           seq  pr_station_id bus_line_no  bus_line_no_seq       station_nm  \
# 0       65286      228000018        10-4                1            용인터미널
# 1       65287      228000018        10-4                2        용인터미널(경유)
# 2       65288      228000018        10-4                3            포브스병원
# 3       65289      228000018        10-4                4             제일교회
# 4       65290      228000018        10-4                5           라이프아파트
# 5       65291      228000018        10-4                6              송담대
# 6       65292      228000018        10-4                7  기후변화체험교육센터.삼삼부락
# 7       65293      228000018        10-4                8         삼삼부락마을회관
# 8       65294      228000018        10-4                9           목동야목농원
# 9       65295      228000018        10-4               10           예비군훈련장
# 10      65296      228000018        10-4               11               별학
# 11      65297      228000018        10-4               12            백마기도원
# 12      65298      228000018        10-4               13              장재미
# 13      65299      228000018        10-4               14           운학초등학교
# 14      65300      228000018        10-4               15           엘에스시스템
# 15      65301      228000018        10-4               16               예직
# 16      65302      228000018        10-4               17              해곡동
# 17      65303      228000018        10-4               18               별미
# 18      65304      228000018        10-4               19             와우정사
# 19      65305      228000018        10-4               20             곱등고개
# 20      65306      228000018        10-4               21               용암
# 21      65307      228000018        10-4               22              물구리
# 22      65308      228000018        10-4               23            사암주유소
# 23      65309      228000018        10-4               24              고당리
# 24      65310      228000018        10-4               25               원삼
# 25      65311      228000018        10-4               26           원삼초등학교
# 26      65312      228000018        10-4               27             독성2리
# 27      65313      228000018        10-4               28             두창7리
# 28      65314      228000018        10-4               29              두창리
# 29      65315      228000018        10-4               30               율곡
# ...       ...            ...         ...              ...              ...
# 37801  191725      241491011        38-1               38        신한에스빌아파트앞
# 37802  191726      241491011        38-1               39          주공1.2단지
# 37803  191727      241491011        38-1               40            주공4단지
# 37804  191728      241491011        38-1               41          신창2차아파트
# 37805  191729      241491011        38-1               42           안화고등학교
# 37806  191730      241491011        38-1               43     안화초교.주공8.9단지
# 37807  191731      241491011        38-1               44             중심상가
# 37808  191732      241491011        38-1               45            롯데시네마
# 37809  191733      241491011        38-1               46              진안동
# 37810  191734      241491011        38-1               47        안용중학교.현충탑
# 37811  191735      241491011        38-1               48            송산동입구
# 37812  191736      241491011        38-1               49          안녕농협삼거리
# 37813  191737      241491011        38-1               50         남수원현대아파트
# 37806   233000071    36372.0     안화초교.주공8.9단지  233000071.0  37.213300
# 37807   233000066    36795.0             중심상가  233000066.0  37.215150
# 37808   233002132    55279.0            롯데시네마  233002132.0  37.214483
# 37809   233000671    36354.0              진안동  233000671.0  37.213017
# 37810   233000670    36328.0        안용중학교.현충탑  233000670.0  37.205567
# 37811   233000669    36318.0            송산동입구  233000669.0  37.205850
# 37812   233000604    36312.0          안녕농협삼거리  233000604.0  37.205300
# 37813   233000603    36307.0         남수원현대아파트  233000603.0  37.207667
# 37814   233000602    36301.0         우남블루존아파트  233000602.0  37.209833
# 37815   233000601    36288.0              용주사  233000601.0  37.210517
# 37816   233001130    36281.0             안녕자원  233001130.0  37.209667
# 37817   233001131    36273.0       지킴이마을.타래치길  233001131.0  37.207000
# 37818   233000600    36262.0              융건릉  233000600.0  37.208050
# 37819   233002234    55122.0             안녕4통  233002234.0  37.212633
# 37820   233000576    36204.0            수원대학교  233000576.0  37.214167
# 37821   233000945    36194.0             와우2리  233000945.0  37.215983
# 37822   233001457    37529.0            와우농협앞  233001457.0  37.218000
# 37823   233002728        NaN              NaN          NaN        NaN
# 37824   233002729        NaN              NaN          NaN        NaN
# 37825   233002731        NaN              NaN          NaN        NaN
# 37826   233002733        NaN              NaN          NaN        NaN
# 37827   233002726        NaN              NaN          NaN        NaN
# 37828   233002959        NaN              NaN          NaN        NaN
# 37829   233002717    55455.0             배양2리  233002717.0  37.226833
# 37830   233532650        NaN              NaN          NaN        NaN
#
#           WGS84경도     관할관청
# 0      127.210100  경기도 용인시
# 1             NaN      NaN
# 2      127.210617  경기도 용인시
# 3      127.213333  경기도 용인시
# 4      127.213767  경기도 용인시
# 5      127.215267  경기도 용인시
# 6      127.224067  경기도 용인시
# 7      127.226167  경기도 용인시
# 8      127.229717  경기도 용인시
# 9      127.230517  경기도 용인시
# 10     127.234033  경기도 용인시
# 11     127.237100  경기도 용인시
# 12     127.240267  경기도 용인시
# 13     127.244833  경기도 용인시
# 14     127.249150  경기도 용인시
# 15     127.257450  경기도 용인시
# 16     127.267867  경기도 용인시
# 17     127.270550  경기도 용인시
# 18     127.276717  경기도 용인시
# 19     127.283100  경기도 용인시
# 20     127.295083  경기도 용인시
# 21     127.300367  경기도 용인시
# 22     127.305250  경기도 용인시
# 23     127.308350  경기도 용인시
# 24     127.310917  경기도 용인시
# 25     127.315700  경기도 용인시
# 26     127.321650  경기도 용인시
# 27     127.337750  경기도 용인시
# 28     127.341167  경기도 용인시
# 29     127.344900  경기도 용인시
# ...           ...      ...
# 37801  127.039517  경기도 화성시
# 37802  127.040917  경기도 화성시
# 37803  127.044500  경기도 화성시
# 37804  127.047583  경기도 화성시
# 37805  127.047517  경기도 화성시
# 37806  127.046083  경기도 화성시
# 37807  127.043750  경기도 화성시
# 37808  127.042450  경기도 화성시
# 37809  127.039300  경기도 화성시
# 37810  127.021917  경기도 화성시
# 37811  127.017783  경기도 화성시
# 37812  127.014250  경기도 화성시
# 37813  127.010517  경기도 화성시
# 37814  127.009233  경기도 화성시
# 37815  127.004300  경기도 화성시
# 37816  127.000467  경기도 화성시
# 37817  126.993017  경기도 화성시
# 37818  126.988700  경기도 화성시
# 37819  126.982783  경기도 화성시
# 37820  126.979150  경기도 화성시
# 37821  126.976317  경기도 화성시
# 37822  126.974633  경기도 화성시
# 37823         NaN      NaN
# 37824         NaN      NaN
# 37825         NaN      NaN
# 37826         NaN      NaN
# 37827         NaN      NaN
# 37828         NaN      NaN
# 37829  126.992067  경기도 화성시
# 37830         NaN      NaN
#
# [37831 rows x 12 columns]

# %%
RouteStationInfo_latlon.isnull().sum()
# Out:
# seq                   0
# pr_station_id         0
# bus_line_no           0
# bus_line_no_seq       0
# station_nm            0
# station_id            0
# mobile_no          2350
# 정류소명               4627
# 표준정류장ID            4627
# WGS84위도            4627
# WGS84경도            4627
# 관할관청               5538
# dtype: int64

# %% [markdown]
# 총 4627개의 결측값이 존재하는 정류장을 어떻게 해야하나...흠...

# %%
# 일단 결측값 데이터 제외
RouteStationInfo_latlon = RouteStationInfo_latlon.dropna()
RouteStationInfo_latlon
# Out:
#           seq  pr_station_id bus_line_no  bus_line_no_seq       station_nm  \
# 0       65286      228000018        10-4                1            용인터미널
# 2       65288      228000018        10-4                3            포브스병원
# 3       65289      228000018        10-4                4             제일교회
# 4       65290      228000018        10-4                5           라이프아파트
# 5       65291      228000018        10-4                6              송담대
# 6       65292      228000018        10-4                7  기후변화체험교육센터.삼삼부락
# 7       65293      228000018        10-4                8         삼삼부락마을회관
# 8       65294      228000018        10-4                9           목동야목농원
# 9       65295      228000018        10-4               10           예비군훈련장
# 10      65296      228000018        10-4               11               별학
# 11      65297      228000018        10-4               12            백마기도원
# 12      65298      228000018        10-4               13              장재미
# 13      65299      228000018        10-4               14           운학초등학교
# 14      65300      228000018        10-4               15           엘에스시스템
# 15      65301      228000018        10-4               16               예직
# 16      65302      228000018        10-4               17              해곡동
# 17      65303      228000018        10-4               18               별미
# 18      65304      228000018        10-4               19             와우정사
# 19      65305      228000018        10-4               20             곱등고개
# 20      65306      228000018        10-4               21               용암
# 21      65307      228000018        10-4               22              물구리
# 22      65308      228000018        10-4               23            사암주유소
# 23      65309      228000018        10-4               24              고당리
# 24      65310      228000018        10-4               25               원삼
# 25      65311      228000018        10-4               26           원삼초등학교
# 26      65312      228000018        10-4               27             독성2리
# 27      65313      228000018        10-4               28             두창7리
# 28      65314      228000018        10-4               29              두창리
# 29      65315      228000018        10-4               30               율곡
# 30      65316      228000018        10-4               31             창동마을
# ...       ...            ...         ...              ...              ...
# 37794  191718      241491011        38-1               31         신한에스빌아파트
# 37795  191719      241491011        38-1               32           동부출장소앞
# 37796  191720      241491011        38-1               33           병점역사거리
# 37797  191721      241491011        38-1               34        홈플러스.벌말초교
# 37798  191722      241491011        38-1               35      우남퍼스트빌3차아파트
# 37799  191723      241491011        38-1               36       신창미션힐.송화초교
# 37800  191724      241491011        38-1               37            동부출장소
# 37801  191725      241491011        38-1               38        신한에스빌아파트앞
# 37802  191726      241491011        38-1               39          주공1.2단지
# 37803  191727      241491011        38-1               40            주공4단지
# 37798  127.041283  경기도 화성시
# 37799  127.038550  경기도 화성시
# 37800  127.035917  경기도 화성시
# 37801  127.039517  경기도 화성시
# 37802  127.040917  경기도 화성시
# 37803  127.044500  경기도 화성시
# 37804  127.047583  경기도 화성시
# 37805  127.047517  경기도 화성시
# 37806  127.046083  경기도 화성시
# 37807  127.043750  경기도 화성시
# 37808  127.042450  경기도 화성시
# 37809  127.039300  경기도 화성시
# 37810  127.021917  경기도 화성시
# 37811  127.017783  경기도 화성시
# 37812  127.014250  경기도 화성시
# 37813  127.010517  경기도 화성시
# 37814  127.009233  경기도 화성시
# 37815  127.004300  경기도 화성시
# 37816  127.000467  경기도 화성시
# 37817  126.993017  경기도 화성시
# 37818  126.988700  경기도 화성시
# 37819  126.982783  경기도 화성시
# 37820  126.979150  경기도 화성시
# 37821  126.976317  경기도 화성시
# 37822  126.974633  경기도 화성시
# 37829  126.992067  경기도 화성시
#
# [32293 rows x 12 columns]

# %%
RouteStationInfo_latlon.reset_index()
# Out:
#        index     seq  pr_station_id bus_line_no  bus_line_no_seq  \
# 0          0   65286      228000018        10-4                1
# 1          2   65288      228000018        10-4                3
# 2          3   65289      228000018        10-4                4
# 3          4   65290      228000018        10-4                5
# 4          5   65291      228000018        10-4                6
# 5          6   65292      228000018        10-4                7
# 6          7   65293      228000018        10-4                8
# 7          8   65294      228000018        10-4                9
# 8          9   65295      228000018        10-4               10
# 9         10   65296      228000018        10-4               11
# 10        11   65297      228000018        10-4               12
# 11        12   65298      228000018        10-4               13
# 12        13   65299      228000018        10-4               14
# 13        14   65300      228000018        10-4               15
# 14        15   65301      228000018        10-4               16
# 15        16   65302      228000018        10-4               17
# 16        17   65303      228000018        10-4               18
# 17        18   65304      228000018        10-4               19
# 18        19   65305      228000018        10-4               20
# 19        20   65306      228000018        10-4               21
# 20        21   65307      228000018        10-4               22
# 21        22   65308      228000018        10-4               23
# 22        23   65309      228000018        10-4               24
# 23        24   65310      228000018        10-4               25
# 24        25   65311      228000018        10-4               26
# 25        26   65312      228000018        10-4               27
# 26        27   65313      228000018        10-4               28
# 27        28   65314      228000018        10-4               29
# 28        29   65315      228000018        10-4               30
# 29        30   65316      228000018        10-4               31
# ...      ...     ...            ...         ...              ...
# 32263  37794  191718      241491011        38-1               31
# 32264  37795  191719      241491011        38-1               32
# 32265  37796  191720      241491011        38-1               33
# 32266  37797  191721      241491011        38-1               34
# 32267  37798  191722      241491011        38-1               35
# 32268  37799  191723      241491011        38-1               36
# 32269  37800  191724      241491011        38-1               37
# 32270  37801  191725      241491011        38-1               38
# 32271  37802  191726      241491011        38-1               39
# 32272  37803  191727      241491011        38-1               40
# 32273  37804  191728      241491011        38-1               41
# 32274  37805  191729      241491011        38-1               42
# 32275  37806  191730      241491011        38-1               43
# 32276  37807  191731      241491011        38-1               44
# 32277  37808  191732      241491011        38-1               45
# 32278  37809  191733      241491011        38-1               46
# 32279  37810  191734      241491011        38-1               47
# 32280  37811  191735      241491011        38-1               48
# 32281  37812  191736      241491011        38-1               49
# 32282  37813  191737      241491011        38-1               50
# 32272            주공4단지   233000087    36369.0            주공4단지  233000087.0
# 32273          신창2차아파트   233000086    36376.0          신창2차아파트  233000086.0
# 32274           안화고등학교   233002394    55281.0           안화고등학교  233002394.0
# 32275     안화초교.주공8.9단지   233000071    36372.0     안화초교.주공8.9단지  233000071.0
# 32276             중심상가   233000066    36795.0             중심상가  233000066.0
# 32277            롯데시네마   233002132    55279.0            롯데시네마  233002132.0
# 32278              진안동   233000671    36354.0              진안동  233000671.0
# 32279        안용중학교.현충탑   233000670    36328.0        안용중학교.현충탑  233000670.0
# 32280            송산동입구   233000669    36318.0            송산동입구  233000669.0
# 32281          안녕농협삼거리   233000604    36312.0          안녕농협삼거리  233000604.0
# 32282         남수원현대아파트   233000603    36307.0         남수원현대아파트  233000603.0
# 32283       우남블루존.원광병원   233000602    36301.0         우남블루존아파트  233000602.0
# 32284              용주사   233000601    36288.0              용주사  233000601.0
# 32285             안녕자원   233001130    36281.0             안녕자원  233001130.0
# 32286       지킴이마을.타래치길   233001131    36273.0       지킴이마을.타래치길  233001131.0
# 32287              융건릉   233000600    36262.0              융건릉  233000600.0
# 32288             안녕4통   233002234    55122.0             안녕4통  233002234.0
# 32289            수원대학교   233000576    36204.0            수원대학교  233000576.0
# 32290             와우2리   233000945    36194.0             와우2리  233000945.0
# 32291            와우농협앞   233001457    37529.0            와우농협앞  233001457.0
# 32292             배양2리   233002717    55455.0             배양2리  233002717.0
#
#          WGS84위도     WGS84경도     관할관청
# 0      37.232783  127.210100  경기도 용인시
# 1      37.235267  127.210617  경기도 용인시
# 2      37.234300  127.213333  경기도 용인시
# 3      37.231483  127.213767  경기도 용인시
# 4      37.228133  127.215267  경기도 용인시
# 5      37.223167  127.224067  경기도 용인시
# 6      37.221133  127.226167  경기도 용인시
# 7      37.218167  127.229717  경기도 용인시
# 8      37.216117  127.230517  경기도 용인시
# 9      37.209367  127.234033  경기도 용인시
# 10     37.206883  127.237100  경기도 용인시
# 11     37.204950  127.240267  경기도 용인시
# 12     37.202383  127.244833  경기도 용인시
# 13     37.200067  127.249150  경기도 용인시
# 14     37.191900  127.257450  경기도 용인시
# 15     37.188533  127.267867  경기도 용인시
# 16     37.187483  127.270550  경기도 용인시
# 17     37.188700  127.276717  경기도 용인시
# 18     37.181867  127.283100  경기도 용인시
# 19     37.177550  127.295083  경기도 용인시
# 20     37.179167  127.300367  경기도 용인시
# 21     37.180733  127.305250  경기도 용인시
# 22     37.176000  127.308350  경기도 용인시
# 23     37.164733  127.310917  경기도 용인시
# 24     37.162583  127.315700  경기도 용인시
# 25     37.159750  127.321650  경기도 용인시
# 26     37.155483  127.337750  경기도 용인시
# 27     37.155667  127.341167  경기도 용인시
# 28     37.154800  127.344900  경기도 용인시
# 29     37.156700  127.349517  경기도 용인시
# ...          ...         ...      ...
# 32263  37.208817  127.038783  경기도 화성시
# 32264  37.208083  127.036133  경기도 화성시
# 32265  37.206917  127.035633  경기도 화성시
# 32266  37.203300  127.038133  경기도 화성시
# 32267  37.198017  127.041283  경기도 화성시
# 32268  37.203300  127.038550  경기도 화성시
# 32269  37.207917  127.035917  경기도 화성시
# 32270  37.208967  127.039517  경기도 화성시
# 32271  37.207967  127.040917  경기도 화성시
# 32272  37.208167  127.044500  경기도 화성시
# 32273  37.209683  127.047583  경기도 화성시
# 32274  37.211433  127.047517  경기도 화성시
# 32275  37.213300  127.046083  경기도 화성시
# 32276  37.215150  127.043750  경기도 화성시
# 32277  37.214483  127.042450  경기도 화성시
# 32278  37.213017  127.039300  경기도 화성시
# 32279  37.205567  127.021917  경기도 화성시
# 32280  37.205850  127.017783  경기도 화성시
# 32281  37.205300  127.014250  경기도 화성시
# 32282  37.207667  127.010517  경기도 화성시
# 32283  37.209833  127.009233  경기도 화성시
# 32284  37.210517  127.004300  경기도 화성시
# 32285  37.209667  127.000467  경기도 화성시
# 32286  37.207000  126.993017  경기도 화성시
# 32287  37.208050  126.988700  경기도 화성시
# 32288  37.212633  126.982783  경기도 화성시
# 32289  37.214167  126.979150  경기도 화성시
# 32290  37.215983  126.976317  경기도 화성시
# 32291  37.218000  126.974633  경기도 화성시
# 32292  37.226833  126.992067  경기도 화성시
#
# [32293 rows x 13 columns]

# %%
RouteStationInfo_latlon.iloc[0][['WGS84위도', 'WGS84경도']]
# Out:
# WGS84위도    37.2328
# WGS84경도     127.21
# Name: 0, dtype: object

# %%
busline = RouteStationInfo_latlon['bus_line_no'].unique()
busline
# Out:
# array(['10-4', '7', '8', '22', '12', '9-1', '73', '2', '3', '9', '11',
#        '6', '2-1', '73-1', '81', '24', '20', '10-1', '10-2', '14', '6-1',
#        '16', '77', '100', '10-6', '10-7', '11-1', '13', '19', '17',
#        '12-1', '11-2', '11-3', '66', '80', '31', '200', '333', '150',
#        '38', '37', '19-1', '10', '15', '23', '29', '1', '2-2', '2-3',
#        '7-1', '1-1', '50-2', '50-1', '50-5', '50-7', '35', '3-2', '3-1',
#        '5', '5-2', '38-1', '35-2', '15-4', '10-8', '1002', '201', '202',
#        '1004', '21', '4', '4-1', '330', '33-1', '5-4', '2-4', '18', '6-2',
#        '6-3', '8-3', '8-2', '8-1', '11-5', '11-4', '1004-1', '340',
#        '1000', '330-1', '25', '26', '27', '340-1', '1008', '33-2', '712',
#        '6001', '116-3', '1001', '8501', '6002', '8155', '6002-1', '710',
#        '203', '8156', '2000A', '2000B', '4403', '6003', '28', '8156(급행)',
#        '4108', '9802', '8472', '8471', '39', 'H6005', '116-5', 'H6007',
#        'H6006', '205', '10-5', '31-3', '720-3', '13-2', '6004', '36-2',
#        '27-1', '27-2', '35-1', '22-2', '17-1', '31-2', '39-1', '36',
#        '36-3', '36-1', '39-2', '721', '116-2', '78', '76', '701', '50-4',
#        '31-1', '50', '79', '709', '709-1', 'H4', 'H5', 'H6(A)', 'H6(B)',
#        '51', '66A', '19-2', '19-3', 'H1', 'H3', 'H2', '20(마산포)',
#        '20(어도동내)', '20(어도펜션)', '공영1(사곳.궁평)', '공영1(매화.궁평)', '공영1(궁평.사곳)',
#        '공영1(지화2리)', '공영2(삼존대광A)', '공영2(송정대광A)', '공영2(금당2리)', '공영2(지화2리)',
#        '공영3(장문지화1)', '공영3(청원.삼존)', '공영4(도말.고포)', '공영3(삼존.청원)',
#        '공영3(금당2리)', '공영4(삼존2.3리)', '공영4(마산.고포)', '공영4(형도.고포)',
#        '공영4(솔미.구렛)', '20-2(용포화석지)', '20-2(천등.고정)', '20-2(용포고정천)',
#        '20-2(용포.고정)', '20-2(천등화석지)', '20-1(백곡리)', '20-1(홍법리)',
#        '20-1(독지리)', '20-3(왕모대시청)', '20-3(당성왕모대)', '20-3(쌍쏭.대광A)', '20-4A',
#        '20-1(고모리)', '공영3(솔미.구렛)', '공영3(지화2리)', '공영4(돌내.형도)', '공영4(돌내독지1)',
#        '공영4(돌내독지2)', '20-4B', '50-2(금강)', '14-4', '88C', '15-5', '13-1',
#        '5-1A', '50-3(안석)', '50-6(대광1차)', '50-8(신외)', '50-4(대광1차)', '5-1B',
#        '50-3(살곶)', '50-6(대광2차)', '50-8(송산)', '22-3(장전)', '22-3(신경대)',
#        'H8', '10-3', '13-3', '13-4', '36A', '36-2A', '39A', '13-4A',
#        '13-7', '13-5', '13-6', 'H7'], dtype=object)

# %% [markdown]
# ```
# 단순히 버스 번호로는 구분지을 수 없음 ㅜㅜ
# 관할관청에 따라서 또 따로 구분해야함!!!
#
# 용인시가 껴있는데
# 화성시만 뽑아내서 쓰면 되는건가??
# ```

# %% [markdown]
# ## 관할 관청 화성시데이터만 뽑아내기

# %%
RouteStationInfo_latlon[RouteStationInfo_latlon['관할관청'] == '경기도 화성시']['bus_line_no'].nunique()
# Out:
# 218

# %%
RouteStationInfo_latlon['bus_line_no'].nunique()
# Out:
# 226

# %%
RouteStationInfo_latlon = RouteStationInfo_latlon[RouteStationInfo_latlon['관할관청'] == '경기도 화성시']

# %% [markdown]
# ## 화성시 버스 노선 전부 나타내기

# %%
All_busline = []

for j in range(len(busline)):
    tmp_busline = RouteStationInfo_latlon[RouteStationInfo_latlon['bus_line_no'] == busline[j]]
    tmp_buslineArr = []
    for i in range(len(tmp_busline)):
        tmp = tmp_busline.iloc[i]
        tmp_buslineArr.append((tmp['WGS84위도'], tmp['WGS84경도']))
    All_busline.append(tmp_buslineArr)

# %%
type(All_busline)
# Out:
# list

# %%
All_busline
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-450bea57eaa9> in <module>
# ----> 1 All_busline
#
# NameError: name 'All_busline' is not defined

# %%
Busline = folium.Map(location = [37.234300,127.213333])

# 왜 앙대닝 흐엉
for i in All_busline.index:
    folium.PolyLine(All_busline[i], color="#ffffff", weight=2.5, opacity=1).add_to(Busline)
# folium.PolyLine(All_busline[0], color="red", weight=2.5, opacity=1).add_to(Busline)
# folium.PolyLine(All_busline[1], color="red", weight=2.5, opacity=1).add_to(Busline)
# folium.PolyLine(All_busline[2], color="red", weight=2.5, opacity=1).add_to(Busline)
# folium.PolyLine(All_busline[3], color="red", weight=2.5, opacity=1).add_to(Busline)
Busline
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-221bdd527818> in <module>
#       2
#       3 # 왜 앙대닝 흐엉
# ----> 4 for i in All_busline.index:
#       5     folium.PolyLine(All_busline[i], color="#ffffff", weight=2.5, opacity=1).add_to(Busline)
#       6 # folium.PolyLine(All_busline[0], color="red", weight=2.5, opacity=1).add_to(Busline)
#
# TypeError: 'builtin_function_or_method' object is not iterable
